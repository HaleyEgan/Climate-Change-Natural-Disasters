# %%
from Code.NaturalDisastersDataCleaner import DisasterData

# %% [markdown]
# # Load our Dataset

# %%
obj = DisasterData(csv_strs = ['Data/natural_disasters_original.csv',
                               'Data/natural_disaster_economic_impact_original.csv'])

# %%
# Display our dataframe's top
obj.disaster_df.head()
# Out:
#                   Entity  Year  \
# 0  All natural disasters  1900
# 1  All natural disasters  1901
# 2  All natural disasters  1902
# 3  All natural disasters  1903
# 4  All natural disasters  1904
#
#    Number of reported natural disasters (reported disasters)
# 0                                                  5
# 1                                                  2
# 2                                                  9
# 3                                                  8
# 4                                                  2

# %% [markdown]
# We noticed that the dataset appears to repeat years in for each disaster type. We also noticed that there were several missing values when we group by the year so we needed to clean those out.
#
# Now let's look at the top of our economic column.

# %%
obj.economic_df.head()
# Out:
#                   Entity  Code  Year  \
# 0  All natural disasters   NaN  1900
# 1  All natural disasters   NaN  1901
# 2  All natural disasters   NaN  1902
# 3  All natural disasters   NaN  1903
# 4  All natural disasters   NaN  1904
#
#    Total economic damage from natural disasters (US$)
# 0                                           30000000
# 1                                                  0
# 2                                                  0
# 3                                          480000000
# 4                                                  0

# %% [markdown]
# Similar story. Let's clean this dataset so that we have one row per year, we have only the columns we care about, and we have ingore the years before 1970 and after 2015.

# %%
# Clean dataset and collect into one dataframe
obj.cleanDf
obj.df.head()
# Out:
#       All natural disasters  Drought  Extreme temperature  Extreme weather  \
# Year
# 1970                   77.0      2.0                  NaN             24.0
# 1971                   61.0      7.0                  1.0             22.0
# 1972                   63.0      7.0                  2.0             26.0
# 1973                   60.0      2.0                  3.0             22.0
# 1974                   68.0      4.0                  NaN             28.0
#
#       Flood  Landslide  Wildfire  TotalCost: All natural disasters  \
# Year
# 1970   31.0        5.0       3.0                      3.076594e+09
# 1971   15.0        5.0       2.0                      1.688589e+09
# 1972   15.0        5.0       3.0                      4.090413e+09
# 1973   20.0        5.0       3.0                      2.407043e+09
# 1974   19.0       10.0       3.0                      4.064944e+09
#
#       TotalCost: Drought  TotalCost: Extreme temperature  \
# Year
# 1970           2100000.0                             NaN
# 1971           3900000.0                     100000000.0
# 1972         187000000.0                             NaN
# 1973          76000000.0                             NaN
# 1974                 NaN                             NaN
#
#       TotalCost: Extreme weather  TotalCost: Flood  TotalCost: Landslide  \
# Year
# 1970                1.064974e+09      1.307770e+09                   NaN
# 1971                2.083890e+08      5.563000e+08                   NaN
# 1972                2.602920e+09      4.344930e+08                   NaN
# 1973                5.392000e+08      1.766493e+09                   NaN
# 1974                3.123017e+09      9.069720e+08            21700000.0
#
#       TotalCost: Wildfire
# Year
# 1970          100000000.0
# 1971                  NaN
# 1972                  NaN
# 1973                  NaN
# 1974                  NaN
